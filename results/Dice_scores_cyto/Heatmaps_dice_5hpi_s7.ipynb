# %% [markdown]
# ## libraries

# %%
import os 
import pandas as pd 
from tabulate import tabulate

# %% [markdown]
# ## fetch directories and files

# %%
ft = "0.5"
ct = "-6.0"

# %%
data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_5hpi_fov13_6Inc_round02_ch0-2-4_s7.txt"
data_ordner_path = f"/home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/"

# %%
data = os.path.join(data_ordner_path, data_pattern)

# %%
print(data)
# Out:
# /home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/ft0.5_ct-6.0_3nt3chan_rep2_1MOI_5hpi_fov13_6Inc_round02_ch0-2-4_s7.txt

# %%
def read_first_line(data):
    with open(data, "r") as data:
        first_line = data.readline()
    return first_line

# %%
read_first_line(data)
# Out:
# 'Generalized Dice Score: 0.8876377643226789\n'

# %%
.readline(<number>)
# Out:
#   Cell In[8], line 1
#     .readline(<number>)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## loop

# %%
fts = [0.0, 0.25, 0.5, 0.75, 1.0]
cts = [-6.0, -5.0, -4.0, -3.0, -2.0, -1.0, 0.0]

# %%
dice_list = []
for ft in fts: 
    for ct in cts: 
        data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_5hpi_fov13_6Inc_round02_ch0-2-4_s7.txt"
        data_path = os.path.join(data_ordner_path, data_pattern)
        sample = f"ft{ft}ct{ct}"
        data = open(data_path, "r")
        first_line = data.readline()
        dice_info = first_line[24:].strip()
        dice_list.append([sample, dice_info])
        #dice_list.append(dice_info)
        

#return erste_zeile[4:].strip()

# %%
print(dice_list)
# Out:
# [['ft0.0ct-6.0', '0.9237889644327254'], ['ft0.0ct-5.0', '0.923605420664332'], ['ft0.0ct-4.0', '0.9224024451919995'], ['ft0.0ct-3.0', '0.9186350476964726'], ['ft0.0ct-2.0', '0.8960198635700154'], ['ft0.0ct-1.0', '0.8398965979059263'], ['ft0.0ct0.0', '0.7613679079479665'], ['ft0.25ct-6.0', '0.7005389381284471'], ['ft0.25ct-5.0', '0.7003164865207527'], ['ft0.25ct-4.0', '0.7037573685381501'], ['ft0.25ct-3.0', '0.7103968552881342'], ['ft0.25ct-2.0', '0.7809379201676047'], ['ft0.25ct-1.0', '0.8064088482229669'], ['ft0.25ct0.0', '0.8024707794019708'], ['ft0.5ct-6.0', '0.8876377643226789'], ['ft0.5ct-5.0', '0.887447334313745'], ['ft0.5ct-4.0', '0.8862459943258173'], ['ft0.5ct-3.0', '0.888543247976338'], ['ft0.5ct-2.0', '0.876045811631886'], ['ft0.5ct-1.0', '0.8592680384270011'], ['ft0.5ct0.0', '0.8271241073045164'], ['ft0.75ct-6.0', '0.9188513661558572'], ['ft0.75ct-5.0', '0.918686915236828'], ['ft0.75ct-4.0', '0.9174890507354653'], ['ft0.75ct-3.0', '0.913688036252968'], ['ft0.75ct-2.0', '0.8953759513655842'], ['ft0.75ct-1.0', '0.864808529755646'], ['ft0.75ct0.0', '0.8271241073045164'], ['ft1.0ct-6.0', '0.9237889644327254'], ['ft1.0ct-5.0', '0.923605420664332'], ['ft1.0ct-4.0', '0.9224024451919995'], ['ft1.0ct-3.0', '0.9186350476964726'], ['ft1.0ct-2.0', '0.8960198635700154'], ['ft1.0ct-1.0', '0.864808529755646'], ['ft1.0ct0.0', '0.8271241073045164']]

# %%
>>> print(tabulate(dice_list, headers=["sample", "score"]))
# Out:
# sample           score
# ------------  --------
# ft0.0ct-6.0   0.923789
# ft0.0ct-5.0   0.923605
# ft0.0ct-4.0   0.922402
# ft0.0ct-3.0   0.918635
# ft0.0ct-2.0   0.89602
# ft0.0ct-1.0   0.839897
# ft0.0ct0.0    0.761368
# ft0.25ct-6.0  0.700539
# ft0.25ct-5.0  0.700316
# ft0.25ct-4.0  0.703757
# ft0.25ct-3.0  0.710397
# ft0.25ct-2.0  0.780938
# ft0.25ct-1.0  0.806409
# ft0.25ct0.0   0.802471
# ft0.5ct-6.0   0.887638
# ft0.5ct-5.0   0.887447
# ft0.5ct-4.0   0.886246
# ft0.5ct-3.0   0.888543
# ft0.5ct-2.0   0.876046
# ft0.5ct-1.0   0.859268
# ft0.5ct0.0    0.827124
# ft0.75ct-6.0  0.918851
# ft0.75ct-5.0  0.918687
# ft0.75ct-4.0  0.917489
# ft0.75ct-3.0  0.913688
# ft0.75ct-2.0  0.895376
# ft0.75ct-1.0  0.864809
# ft0.75ct0.0   0.827124
# ft1.0ct-6.0   0.923789
# ft1.0ct-5.0   0.923605
# ft1.0ct-4.0   0.922402
# ft1.0ct-3.0   0.918635
# ft1.0ct-2.0   0.89602
# ft1.0ct-1.0   0.864809
# ft1.0ct0.0    0.827124

# %% [markdown]
# ## Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

#Momentan ist dice_ist noch eine Liste von listen - hier in dataframe umgewandelt mit keywörtern
df = pd.DataFrame(dice_list, columns=['sample', 'score'])

df['ft'] = df['sample'].apply(lambda x: float(x.split('ct')[0][2:]))
df['ct'] = df['sample'].apply(lambda x: float(x.split('ct')[1]))

#Zahlen müssen als float interpretiert werden, sonst crasht seaborn irgendwie immer
df['score'] = df['score'].astype(float)

#ändern der Reihenfolge da 0.0 technically ja über 1.0 stehen muss
df['ft'] = pd.Categorical(df['ft'], categories=[0.0, 1.0, 0.75, 0.5, 0.25], ordered=True)

pivot_table = df.pivot(index='ft', columns='ct', values='score')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt=".3f")
plt.title('Heatmap of Dice Scores')
plt.show()

print(tabulate(df, headers="keys", tablefmt="pipe"))
# Out:
# |    | sample       |    score |   ft |   ct |
# |---:|:-------------|---------:|-----:|-----:|
# |  0 | ft0.0ct-6.0  | 0.923789 | 0    |   -6 |
# |  1 | ft0.0ct-5.0  | 0.923605 | 0    |   -5 |
# |  2 | ft0.0ct-4.0  | 0.922402 | 0    |   -4 |
# |  3 | ft0.0ct-3.0  | 0.918635 | 0    |   -3 |
# |  4 | ft0.0ct-2.0  | 0.89602  | 0    |   -2 |
# |  5 | ft0.0ct-1.0  | 0.839897 | 0    |   -1 |
# |  6 | ft0.0ct0.0   | 0.761368 | 0    |    0 |
# |  7 | ft0.25ct-6.0 | 0.700539 | 0.25 |   -6 |
# |  8 | ft0.25ct-5.0 | 0.700316 | 0.25 |   -5 |
# |  9 | ft0.25ct-4.0 | 0.703757 | 0.25 |   -4 |
# | 10 | ft0.25ct-3.0 | 0.710397 | 0.25 |   -3 |
# | 11 | ft0.25ct-2.0 | 0.780938 | 0.25 |   -2 |
# | 12 | ft0.25ct-1.0 | 0.806409 | 0.25 |   -1 |
# | 13 | ft0.25ct0.0  | 0.802471 | 0.25 |    0 |
# | 14 | ft0.5ct-6.0  | 0.887638 | 0.5  |   -6 |
# | 15 | ft0.5ct-5.0  | 0.887447 | 0.5  |   -5 |
# | 16 | ft0.5ct-4.0  | 0.886246 | 0.5  |   -4 |
# | 17 | ft0.5ct-3.0  | 0.888543 | 0.5  |   -3 |
# | 18 | ft0.5ct-2.0  | 0.876046 | 0.5  |   -2 |
# | 19 | ft0.5ct-1.0  | 0.859268 | 0.5  |   -1 |
# | 20 | ft0.5ct0.0   | 0.827124 | 0.5  |    0 |
# | 21 | ft0.75ct-6.0 | 0.918851 | 0.75 |   -6 |
# | 22 | ft0.75ct-5.0 | 0.918687 | 0.75 |   -5 |
# | 23 | ft0.75ct-4.0 | 0.917489 | 0.75 |   -4 |
# | 24 | ft0.75ct-3.0 | 0.913688 | 0.75 |   -3 |
# | 25 | ft0.75ct-2.0 | 0.895376 | 0.75 |   -2 |
# | 26 | ft0.75ct-1.0 | 0.864809 | 0.75 |   -1 |
# | 27 | ft0.75ct0.0  | 0.827124 | 0.75 |    0 |
# | 28 | ft1.0ct-6.0  | 0.923789 | 1    |   -6 |
# | 29 | ft1.0ct-5.0  | 0.923605 | 1    |   -5 |
# | 30 | ft1.0ct-4.0  | 0.922402 | 1    |   -4 |
# | 31 | ft1.0ct-3.0  | 0.918635 | 1    |   -3 |
# | 32 | ft1.0ct-2.0  | 0.89602  | 1    |   -2 |
# | 33 | ft1.0ct-1.0  | 0.864809 | 1    |   -1 |
# | 34 | ft1.0ct0.0   | 0.827124 | 1    |    0 |
