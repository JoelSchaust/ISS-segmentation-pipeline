# %% [markdown]
# ## libraries

# %%
import os 
import pandas as pd 
from tabulate import tabulate

# %% [markdown]
# ## fetch directories and files

# %%
ft = "0.5"
ct = "-6.0"

# %%
data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s5.txt"
data_ordner_path = f"/home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/"

# %%
data = os.path.join(data_ordner_path, data_pattern)

# %%
print(data)
# Out:
# /home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/ft0.5_ct-6.0_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s5.txt

# %%
def read_first_line(data):
    with open(data, "r") as data:
        first_line = data.readline()
    return first_line

# %%
read_first_line(data)
# Out:
# 'Generalized Dice Score: 0.9100749087721954\n'

# %% [markdown]
# ## loop

# %%
fts = [0.0, 0.25, 0.5, 0.75, 1.0]
cts = [-6.0, -5.0, -4.0, -3.0, -2.0, -1.0, 0.0]

# %%
dice_list = []
for ft in fts: 
    for ct in cts: 
        data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s5.txt"
        data_path = os.path.join(data_ordner_path, data_pattern)
        sample = f"ft{ft}ct{ct}"
        data = open(data_path, "r")
        first_line = data.readline()
        dice_info = first_line[24:].strip()
        dice_list.append([sample, dice_info])
        #dice_list.append(dice_info)
        

#return erste_zeile[4:].strip()

# %%
print(dice_list)
# Out:
# [['ft0.0ct-6.0', '0.928154494995143'], ['ft0.0ct-5.0', '0.9280738840139681'], ['ft0.0ct-4.0', '0.9271306307738583'], ['ft0.0ct-3.0', '0.9242795149013229'], ['ft0.0ct-2.0', '0.9143390890715337'], ['ft0.0ct-1.0', '0.8892752090414489'], ['ft0.0ct0.0', '0.8574814597891319'], ['ft0.25ct-6.0', '0.6619975255708187'], ['ft0.25ct-5.0', '0.6619015498314205'], ['ft0.25ct-4.0', '0.6609447115659874'], ['ft0.25ct-3.0', '0.7191367191913828'], ['ft0.25ct-2.0', '0.7585303724534751'], ['ft0.25ct-1.0', '0.8133520635587284'], ['ft0.25ct0.0', '0.8101114893332326'], ['ft0.5ct-6.0', '0.9100749087721954'], ['ft0.5ct-5.0', '0.9099852500738762'], ['ft0.5ct-4.0', '0.9089487868619966'], ['ft0.5ct-3.0', '0.9061071094830503'], ['ft0.5ct-2.0', '0.8962865494115275'], ['ft0.5ct-1.0', '0.8833785284528399'], ['ft0.5ct0.0', '0.855860341558376'], ['ft0.75ct-6.0', '0.9354496660715108'], ['ft0.75ct-5.0', '0.9353652929525513'], ['ft0.75ct-4.0', '0.9344114953313924'], ['ft0.75ct-3.0', '0.9316835929103353'], ['ft0.75ct-2.0', '0.9143390890715337'], ['ft0.75ct-1.0', '0.8892752090414489'], ['ft0.75ct0.0', '0.8574814597891319'], ['ft1.0ct-6.0', '0.928154494995143'], ['ft1.0ct-5.0', '0.9280738840139681'], ['ft1.0ct-4.0', '0.9271306307738583'], ['ft1.0ct-3.0', '0.9242795149013229'], ['ft1.0ct-2.0', '0.9143390890715337'], ['ft1.0ct-1.0', '0.8892752090414489'], ['ft1.0ct0.0', '0.8574814597891319']]

# %%
>>> print(tabulate(dice_list, headers=["sample", "score"]))
# Out:
# sample           score
# ------------  --------
# ft0.0ct-6.0   0.928154
# ft0.0ct-5.0   0.928074
# ft0.0ct-4.0   0.927131
# ft0.0ct-3.0   0.92428
# ft0.0ct-2.0   0.914339
# ft0.0ct-1.0   0.889275
# ft0.0ct0.0    0.857481
# ft0.25ct-6.0  0.661998
# ft0.25ct-5.0  0.661902
# ft0.25ct-4.0  0.660945
# ft0.25ct-3.0  0.719137
# ft0.25ct-2.0  0.75853
# ft0.25ct-1.0  0.813352
# ft0.25ct0.0   0.810111
# ft0.5ct-6.0   0.910075
# ft0.5ct-5.0   0.909985
# ft0.5ct-4.0   0.908949
# ft0.5ct-3.0   0.906107
# ft0.5ct-2.0   0.896287
# ft0.5ct-1.0   0.883379
# ft0.5ct0.0    0.85586
# ft0.75ct-6.0  0.93545
# ft0.75ct-5.0  0.935365
# ft0.75ct-4.0  0.934411
# ft0.75ct-3.0  0.931684
# ft0.75ct-2.0  0.914339
# ft0.75ct-1.0  0.889275
# ft0.75ct0.0   0.857481
# ft1.0ct-6.0   0.928154
# ft1.0ct-5.0   0.928074
# ft1.0ct-4.0   0.927131
# ft1.0ct-3.0   0.92428
# ft1.0ct-2.0   0.914339
# ft1.0ct-1.0   0.889275
# ft1.0ct0.0    0.857481

# %% [markdown]
# ## Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

#Momentan ist dice_ist noch eine Liste von listen - hier in dataframe umgewandelt mit keywörtern
df = pd.DataFrame(dice_list, columns=['sample', 'score'])

df['ft'] = df['sample'].apply(lambda x: float(x.split('ct')[0][2:]))
df['ct'] = df['sample'].apply(lambda x: float(x.split('ct')[1]))

#Zahlen müssen als float interpretiert werden, sonst crasht seaborn irgendwie immer
df['score'] = df['score'].astype(float)

#ändern der Reihenfolge da 0.0 technically ja über 1.0 stehen muss
df['ft'] = pd.Categorical(df['ft'], categories=[0.0, 1.0, 0.75, 0.5, 0.25], ordered=True)

pivot_table = df.pivot(index='ft', columns='ct', values='score')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt=".3f")
plt.title('Heatmap of Dice Scores')
plt.show()

print(tabulate(df, headers="keys", tablefmt="pipe"))
# Out:
# |    | sample       |    score |   ft |   ct |
# |---:|:-------------|---------:|-----:|-----:|
# |  0 | ft0.0ct-6.0  | 0.928154 | 0    |   -6 |
# |  1 | ft0.0ct-5.0  | 0.928074 | 0    |   -5 |
# |  2 | ft0.0ct-4.0  | 0.927131 | 0    |   -4 |
# |  3 | ft0.0ct-3.0  | 0.92428  | 0    |   -3 |
# |  4 | ft0.0ct-2.0  | 0.914339 | 0    |   -2 |
# |  5 | ft0.0ct-1.0  | 0.889275 | 0    |   -1 |
# |  6 | ft0.0ct0.0   | 0.857481 | 0    |    0 |
# |  7 | ft0.25ct-6.0 | 0.661998 | 0.25 |   -6 |
# |  8 | ft0.25ct-5.0 | 0.661902 | 0.25 |   -5 |
# |  9 | ft0.25ct-4.0 | 0.660945 | 0.25 |   -4 |
# | 10 | ft0.25ct-3.0 | 0.719137 | 0.25 |   -3 |
# | 11 | ft0.25ct-2.0 | 0.75853  | 0.25 |   -2 |
# | 12 | ft0.25ct-1.0 | 0.813352 | 0.25 |   -1 |
# | 13 | ft0.25ct0.0  | 0.810111 | 0.25 |    0 |
# | 14 | ft0.5ct-6.0  | 0.910075 | 0.5  |   -6 |
# | 15 | ft0.5ct-5.0  | 0.909985 | 0.5  |   -5 |
# | 16 | ft0.5ct-4.0  | 0.908949 | 0.5  |   -4 |
# | 17 | ft0.5ct-3.0  | 0.906107 | 0.5  |   -3 |
# | 18 | ft0.5ct-2.0  | 0.896287 | 0.5  |   -2 |
# | 19 | ft0.5ct-1.0  | 0.883379 | 0.5  |   -1 |
# | 20 | ft0.5ct0.0   | 0.85586  | 0.5  |    0 |
# | 21 | ft0.75ct-6.0 | 0.93545  | 0.75 |   -6 |
# | 22 | ft0.75ct-5.0 | 0.935365 | 0.75 |   -5 |
# | 23 | ft0.75ct-4.0 | 0.934411 | 0.75 |   -4 |
# | 24 | ft0.75ct-3.0 | 0.931684 | 0.75 |   -3 |
# | 25 | ft0.75ct-2.0 | 0.914339 | 0.75 |   -2 |
# | 26 | ft0.75ct-1.0 | 0.889275 | 0.75 |   -1 |
# | 27 | ft0.75ct0.0  | 0.857481 | 0.75 |    0 |
# | 28 | ft1.0ct-6.0  | 0.928154 | 1    |   -6 |
# | 29 | ft1.0ct-5.0  | 0.928074 | 1    |   -5 |
# | 30 | ft1.0ct-4.0  | 0.927131 | 1    |   -4 |
# | 31 | ft1.0ct-3.0  | 0.92428  | 1    |   -3 |
# | 32 | ft1.0ct-2.0  | 0.914339 | 1    |   -2 |
# | 33 | ft1.0ct-1.0  | 0.889275 | 1    |   -1 |
# | 34 | ft1.0ct0.0   | 0.857481 | 1    |    0 |
