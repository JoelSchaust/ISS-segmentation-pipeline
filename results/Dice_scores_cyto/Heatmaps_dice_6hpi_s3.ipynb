# %% [markdown]
# ## libraries

# %%
import os 
import pandas as pd 
from tabulate import tabulate

# %% [markdown]
# ## fetch directories and files

# %%
ft = "0.5"
ct = "-6.0"

# %%
data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s3.txt"
data_ordner_path = f"/home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/"

# %%
data = os.path.join(data_ordner_path, data_pattern)

# %%
print(data)
# Out:
# /home/s361852/Schreibtisch/in-situ-seq-segmentation/data/segmentation_3nt_3chan_non_mutant/Verdünnungsreihe_v3/postprocessed/Dice_scores_correct/ft0.5_ct-6.0_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s3.txt

# %%
def read_first_line(data):
    with open(data, "r") as data:
        first_line = data.readline()
    return first_line

# %%
read_first_line(data)
# Out:
# 'Generalized Dice Score: 0.8854852342349808\n'

# %% [markdown]
# ## loop

# %%
fts = [0.0, 0.25, 0.5, 0.75, 1.0]
cts = [-6.0, -5.0, -4.0, -3.0, -2.0, -1.0, 0.0]

# %%
dice_list = []
for ft in fts: 
    for ct in cts: 
        data_pattern = f"ft{ft}_ct{ct}_3nt3chan_rep2_1MOI_6hpi_fov15_6Inc_round02_ch0-2-4_s3.txt"
        data_path = os.path.join(data_ordner_path, data_pattern)
        sample = f"ft{ft}ct{ct}"
        data = open(data_path, "r")
        first_line = data.readline()
        dice_info = first_line[24:].strip()
        dice_list.append([sample, dice_info])
        #dice_list.append(dice_info)
        

#return erste_zeile[4:].strip()

# %%
print(dice_list)
# Out:
# [['ft0.0ct-6.0', '0.8440881249712795'], ['ft0.0ct-5.0', '0.691327513744559'], ['ft0.0ct-4.0', '0.9242796187106334'], ['ft0.0ct-3.0', '0.9181733605236255'], ['ft0.0ct-2.0', '0.8920174390168624'], ['ft0.0ct-1.0', '0.852239603571753'], ['ft0.0ct0.0', '0.7993804583424515'], ['ft0.25ct-6.0', '0.6400070286263642'], ['ft0.25ct-5.0', '0.646417481091519'], ['ft0.25ct-4.0', '0.6649159849653836'], ['ft0.25ct-3.0', '0.6788727170635532'], ['ft0.25ct-2.0', '0.7667262249411257'], ['ft0.25ct-1.0', '0.812498000963227'], ['ft0.25ct0.0', '0.7899155784562861'], ['ft0.5ct-6.0', '0.8854852342349808'], ['ft0.5ct-5.0', '0.8848876107455402'], ['ft0.5ct-4.0', '0.8821134620802872'], ['ft0.5ct-3.0', '0.8793193023618407'], ['ft0.5ct-2.0', '0.8726698643053087'], ['ft0.5ct-1.0', '0.8433002114978742'], ['ft0.5ct0.0', '0.8080209394140827'], ['ft0.75ct-6.0', '0.9242345193320277'], ['ft0.75ct-5.0', '0.9236436633084942'], ['ft0.75ct-4.0', '0.9209513672499383'], ['ft0.75ct-3.0', '0.9177869750150031'], ['ft0.75ct-2.0', '0.8941135278515866'], ['ft0.75ct-1.0', '0.8522393406909085'], ['ft0.75ct0.0', '0.8030117276589056'], ['ft1.0ct-6.0', '0.7412179805165345'], ['ft1.0ct-5.0', '0.8165686104496356'], ['ft1.0ct-4.0', '0.9242796747520695'], ['ft1.0ct-3.0', '0.9181734175808529'], ['ft1.0ct-2.0', '0.8919578432118536'], ['ft1.0ct-1.0', '0.8522393406909085'], ['ft1.0ct0.0', '0.8030117276589056']]

# %%
>>> print(tabulate(dice_list, headers=["sample", "score"]))
# Out:
# sample           score
# ------------  --------
# ft0.0ct-6.0   0.844088
# ft0.0ct-5.0   0.691328
# ft0.0ct-4.0   0.92428
# ft0.0ct-3.0   0.918173
# ft0.0ct-2.0   0.892017
# ft0.0ct-1.0   0.85224
# ft0.0ct0.0    0.79938
# ft0.25ct-6.0  0.640007
# ft0.25ct-5.0  0.646417
# ft0.25ct-4.0  0.664916
# ft0.25ct-3.0  0.678873
# ft0.25ct-2.0  0.766726
# ft0.25ct-1.0  0.812498
# ft0.25ct0.0   0.789916
# ft0.5ct-6.0   0.885485
# ft0.5ct-5.0   0.884888
# ft0.5ct-4.0   0.882113
# ft0.5ct-3.0   0.879319
# ft0.5ct-2.0   0.87267
# ft0.5ct-1.0   0.8433
# ft0.5ct0.0    0.808021
# ft0.75ct-6.0  0.924235
# ft0.75ct-5.0  0.923644
# ft0.75ct-4.0  0.920951
# ft0.75ct-3.0  0.917787
# ft0.75ct-2.0  0.894114
# ft0.75ct-1.0  0.852239
# ft0.75ct0.0   0.803012
# ft1.0ct-6.0   0.741218
# ft1.0ct-5.0   0.816569
# ft1.0ct-4.0   0.92428
# ft1.0ct-3.0   0.918173
# ft1.0ct-2.0   0.891958
# ft1.0ct-1.0   0.852239
# ft1.0ct0.0    0.803012

# %% [markdown]
# ## Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

#Momentan ist dice_ist noch eine Liste von listen - hier in dataframe umgewandelt mit keywörtern
df = pd.DataFrame(dice_list, columns=['sample', 'score'])

df['ft'] = df['sample'].apply(lambda x: float(x.split('ct')[0][2:]))
df['ct'] = df['sample'].apply(lambda x: float(x.split('ct')[1]))

#Zahlen müssen als float interpretiert werden, sonst crasht seaborn irgendwie immer
df['score'] = df['score'].astype(float)

#ändern der Reihenfolge da 0.0 technically ja über 1.0 stehen muss
df['ft'] = pd.Categorical(df['ft'], categories=[0.0, 1.0, 0.75, 0.5, 0.25], ordered=True)

pivot_table = df.pivot(index='ft', columns='ct', values='score')

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt=".3f")
plt.title('Heatmap of Dice Scores')
plt.show()

print(tabulate(df, headers="keys", tablefmt="pipe"))
# Out:
# |    | sample       |    score |   ft |   ct |
# |---:|:-------------|---------:|-----:|-----:|
# |  0 | ft0.0ct-6.0  | 0.844088 | 0    |   -6 |
# |  1 | ft0.0ct-5.0  | 0.691328 | 0    |   -5 |
# |  2 | ft0.0ct-4.0  | 0.92428  | 0    |   -4 |
# |  3 | ft0.0ct-3.0  | 0.918173 | 0    |   -3 |
# |  4 | ft0.0ct-2.0  | 0.892017 | 0    |   -2 |
# |  5 | ft0.0ct-1.0  | 0.85224  | 0    |   -1 |
# |  6 | ft0.0ct0.0   | 0.79938  | 0    |    0 |
# |  7 | ft0.25ct-6.0 | 0.640007 | 0.25 |   -6 |
# |  8 | ft0.25ct-5.0 | 0.646417 | 0.25 |   -5 |
# |  9 | ft0.25ct-4.0 | 0.664916 | 0.25 |   -4 |
# | 10 | ft0.25ct-3.0 | 0.678873 | 0.25 |   -3 |
# | 11 | ft0.25ct-2.0 | 0.766726 | 0.25 |   -2 |
# | 12 | ft0.25ct-1.0 | 0.812498 | 0.25 |   -1 |
# | 13 | ft0.25ct0.0  | 0.789916 | 0.25 |    0 |
# | 14 | ft0.5ct-6.0  | 0.885485 | 0.5  |   -6 |
# | 15 | ft0.5ct-5.0  | 0.884888 | 0.5  |   -5 |
# | 16 | ft0.5ct-4.0  | 0.882113 | 0.5  |   -4 |
# | 17 | ft0.5ct-3.0  | 0.879319 | 0.5  |   -3 |
# | 18 | ft0.5ct-2.0  | 0.87267  | 0.5  |   -2 |
# | 19 | ft0.5ct-1.0  | 0.8433   | 0.5  |   -1 |
# | 20 | ft0.5ct0.0   | 0.808021 | 0.5  |    0 |
# | 21 | ft0.75ct-6.0 | 0.924235 | 0.75 |   -6 |
# | 22 | ft0.75ct-5.0 | 0.923644 | 0.75 |   -5 |
# | 23 | ft0.75ct-4.0 | 0.920951 | 0.75 |   -4 |
# | 24 | ft0.75ct-3.0 | 0.917787 | 0.75 |   -3 |
# | 25 | ft0.75ct-2.0 | 0.894114 | 0.75 |   -2 |
# | 26 | ft0.75ct-1.0 | 0.852239 | 0.75 |   -1 |
# | 27 | ft0.75ct0.0  | 0.803012 | 0.75 |    0 |
# | 28 | ft1.0ct-6.0  | 0.741218 | 1    |   -6 |
# | 29 | ft1.0ct-5.0  | 0.816569 | 1    |   -5 |
# | 30 | ft1.0ct-4.0  | 0.92428  | 1    |   -4 |
# | 31 | ft1.0ct-3.0  | 0.918173 | 1    |   -3 |
# | 32 | ft1.0ct-2.0  | 0.891958 | 1    |   -2 |
# | 33 | ft1.0ct-1.0  | 0.852239 | 1    |   -1 |
# | 34 | ft1.0ct0.0   | 0.803012 | 1    |    0 |
